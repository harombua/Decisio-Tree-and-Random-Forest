# %% [markdown]
# # Decision Tree and Random Forest in Classification Task.

# %% [markdown]
# > ## Business Case:-
# >### Based on given features  find out whether an employee will leave the company or not.

# %% [markdown]
# ## Domain analysis
# + **Age:-** This the age of the employee. The age is a continous data.
# + **Attrition:-** Commonly referred to as a ‘churn rate,’ a company’s attrition rate is the rate at which people leave. If you break it down, it is the number of people who have left the company, divided by the average number of employees over a period of time. Typically, it is expressed as a percentage (%). Here instead of rate we have Yes or No. This is `Our Target Variable`
# + **BusinessTravel:-** Is a feature with ordinal data that indicates how frequent the employees travels. Business travel influences how employees feel about their current company and hence it is a factor that can determine attrition. There seems to be 3 unique values (Rarely, Frequently, Not travel)
# + **DailyRate:-** The prescribed amount of pay for a given job of work paid for by the day or hour. This can either mutivate or discourage an employee and hence has significance as much as attrition is concerned. It is a feature with continous data.
# + **Department:-** This is the area of special expertise or responsibility. The feature has 3 unique departments (Sales, Research & Development and Human Resource)
# + **DistanceFromHome:-** This is the distance in which each employee covers to reach the work place. It is a column of discrete data.
# + **Education:-** Indicates the level of education of the employee and here the feature has discrete data.
# + **EducationField:-** This is the area/field of specialization of the employee. The feature has categorical-nominal data.
# + **EmployeeCount:-** This is redundat feature in the data that counts each employer,
# + **EmployeeNumber:-** Again a redundant feature that bears the index of each employee.
# + **EnvironmentSatisfaction:-** This refers to how contented a person feels with respect to the physical setting in question. Here the data is discrete.
# + **Gender:-** Either of the two sexes (male and female), especially when considered with reference to social and cultural differences rather than biological ones. The term is also used more broadly to denote a range of identities that do not correspond to established ideas of male and female.
# + **HourlyRate:-** This is the amount of money that is charged, paid, or earned for every hour worked: The data is continous
# + **JobInvolvement:-** This is the degree to which a person psychologically identifies with his or her job. A person who has a high level of job involvement usually obtains major life satisfaction from the job. It appears to be a feature with discrete values.
# + **MaritalStatus:-** One's situation with regard to whether one is single, married, separated, divorced, or widowed.
# + **MonthlyIncome:-** It means  the gross countable income received or projected to be received during the month or the monthly equivalent.
# + **MonthlyRate:-** It means a charge for services based on a thirty (30) day period.
# + **JobLevel:-** Job levels, also known as job grades and classifications, set the responsibility level and expectations of roles at your organization. They may be further defined by impact, seniority, knowledge, skills, or job title, and are often associated with a pay band. Here we have 5 categories of job levels (1,2,3,4,5).
# + **NumCompaniesWorked:-** This variable records the number of companies an employee has worked for prior to joining this company.
# + **Over18:-** This seems to be a constant feature that has Y as its values, to show that someone is over 18 years of age. All are over 18 years.
# + **OverTime:-** This variable describes whether or not the employee regularly works overtime; the responses are either “Yes” or “No”.
# + **PercentSalaryHike:-** An increment or a salary hike is the increase in the current salary of any employee by a certain amount. It is expressed as a percentage of the current salary. Increments can be given quarterly, half-yearly, or yearly and are also used by employees to negotiate their salaries with a new employer.
# + **PerformanceRating:-** Performance rating is the step in the work measurement in which the analyst observes the worker's performance and records a value representing that performance relative to the analyst's concept of standard performance. Performance rating helps people do their jobs better, identifies training and education needs, assigns people to work they can excel in, and maintains fairness in salaries, benefits, promotion, hiring, and firing. The scale is mostly from 1-5.
# + **RelationshipSatisfaction:-** Relationship satisfaction is the subjective evaluation of one’s relationship. Relationship satisfaction is not a property of a relationship; it is a subjective experience and opinion. A scale is used as a measuring tool with rating from 1-5.
# + **StandardHours:-** This is a constant feature. Standard hours allowed is the number of hours of production time that should have been used during an accounting period. It is based on the actual number of units produced, multiplied by the standard hours per unit. The concept is most commonly employed in manufacturing operations where a large number of units are to be produced, and attaining a profit requires that close attention be paid to the number of hours of production.
# + **StockOptionLevel:-** Stock options are a benefit often associated with startup companies, which may issue them in order to reward early employees when and if the company goes public. They are awarded by some fast-growing companies as an incentive for employees to work towards growing the value of the company's shares.
# + **TotalWorkingYears:-** Number of years the employee has worked.
# + **TrainingTimesLastYear:-** Amount of time spend training the employee, could be days or months.
# + **WorkLifeBalance:-** Work-life balance is a term used for the idea that you need time for both work and other aspects of life, whether those are family-related or personal interests. The saying goes that ‘all work and no play makes Jack a dull boy’. But work, or at least some kind of contributory effort, whether paid or voluntary, is often recognised as being important for personal satisfaction, so it seems likely that ‘all play’ would be dull too.
# + **YearsAtCompany:-** The number of years an employee has been in the company.
# + **YearsInCurrentRole:-** The number of years an employee has been in their current job role.
# + **YearsSinceLastPromotion:-** The number of years since the employee was promoted.
# + **YearsWithCurrManager:-** The number of years the employee has worked under the current manager.
# + **JobSatisfaction:-** This is the level of contentment employees feel with their job.

# %%
## Importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
## Loading the data
data=pd.read_csv('HR-Employee-Attrition.csv')

# %%
# View all columns in the data.
pd.set_option('display.max_columns',None)

# %%
# Displaying the first 5 rows
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
data.shape
# Out:
# (1470, 35)

# %%
## Getting some rows
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',None)

# %% [markdown]
# >## Basic Checks

# %%
# Checking the last 5 rows.
data.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  EnvironmentSatisfaction Gender  HourlyRate  \
# 1465            2061                        3   Male          41
# ...

# %%
# Descriptive statistics of the numerical columns
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
# Describing categorical data
data.describe(include=['O'])
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       1470           1470                    1470           1470   1470
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        1233           1043                     961            606    882
#
#                 JobRole MaritalStatus Over18 OverTime
# count              1470          1470   1470     1470
# unique                9             3      1        2
# top     Sales Executive       Married      Y       No
# freq                326           673   1470     1054

# %%
# Basic information about the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# ### Insights from the basic checks.
# + We have 1470 observations (rows) and 35 columns without missing values. We have 26 features that are numeric (int64 datatypes) and 9 features that are categorical (object).
# + Employee count and StandardHour are constant features since they have a standard variation of 0. Hence they need not be analysed.

# %% [markdown]
# >## Exploratory Data Analysis

# %% [markdown]
# ####  a.Univariate Analysis of all the features.
# If you sweetviz is not installed, it can be installed i Jupyter notebook through this code: `!pip install sweetviz`

# %%
import sweetviz as sv
my_report = sv.analyze(data)
my_report.show_html() # Default arguments will generate to "SWEETVIZ_REPORT.html"

# %% [markdown]
# ### Insights from univariate analysis
# **Age** This feature follows a normal distribution with more employees being between 2.5 to 50 years of age. This is normally the working age for many governments or companies.
#
# **Attrition** From the plot, we have more employees of category "No" (over 80% of the data) meaning they didnt leave while less tha 20% did leave the company.
#
# **BusinessTravel** 71% of our data has employees that travel rarely, 19% travel frequently while the remaining 10%  do not travel.
#
# **Daily Rate** The maximum daily rate is 1500 with almost uniform distribution in all categories of daily rate.
#
# **Department** There are 3 departments with Research and Development department at the top having 65.4% of the total population followed by Sales department with 30.3% and lastly is 4.3%.
#
# **DistanceFromHome** Upto a diastance of 10, The lesser the distance from home the more the number of employees. Past 10, the number of employees is fairly constant at less than 5% in category.
#
# **Education** In a scale of 1 to 5, employees with education matching to scale 3 are the most in the entire dataset totalling to 39.9% followed by scale 4 with 27%, then scale 2 with 19.2% , scale 1 with 11.6% and lastly is scale 5 with 3.3%. This shows that the education level is fair for the employees since many are rated above the scale of 2.
#
# **EducationField** We have 6 education fields from which the employees come. Life Science has the most employees with 42%, followed by medical with 32%, then Marketting with 11%, Technical degree with 9%, then Others with 6% and finally Human Resources with 2% of the total dateset.
#
# **EnvironmentSatisfaction** On a 1-4 scale,  4-Very satisfied, 3-Satisfied, 2-Dissatisfied, and 1-Very dissatisfiedthe employees in scale 3 meaning Satisfied are 31% closely followed by those with environment satisfaction of scale 4 meaning Very Satisfied, followed by those with scale 2 which means Dissatisfied with 20% and lastly is scale 1, the very dissatisfied group with 19%. This shows that the environment his good since 61% have rated it between 3 to 4 and a few 39% at 1 and 2.
#
# **Gender** 60% of the dataset is composed of male, while female form the remaining 40%.
#
# **HourlyRate** There seems to be no trend in the dataset concerning the distribution of hourly rate.
#
# **JobInvolvement** On a scale ranging from 1-4, 4-Very involved, 3-Involved, 2-Not Involved, and 1-Not Very Involved , most of the employees (59%) are involved, 26% are Not involved, 6% are not very involved and only 10% are Very Involved.
#
# **JobLevel** There seems to be 5 categories of Job level. As the job group increases from group 1 to 5, the number of employees in each job group increases, from 37% in job group 1 to job group 5 with 5% of the total employees in the dataset.
#
# **JobRole** There are 10 job roles for all employees in the dataset. Sales Executive has 22% of the employees, Research Scientist has 20%, Laboratory Technitian has 18%, Manufacturing Director follows with 10%, then Healthcare Representative has 9%,Manager has 8%, Sales Representative with 6%, Research Director with 5% and lastly Human Resources has 4% of the total job roles in the dataset. It appears this is a manufacturing company.
#
# **JobSatisfaction** On a scale ranging from 1-4, 4-Very satisfied, 3-Satisfied, 2-Dissatisfied, and 1-Very dissatisfied, most of the employees (31%) are Very satisfied, 30% are satisfied, 20% are very dissatisfied and 19% are Disatisfied. It appears that 61% are satisfied while 39% are disatisfied. Thus the company is good.
#
# **MaritalStatus** The married category has 46% of the entire dataset and is therefore the majority, single follow with 40% while the divorced category has 22% of the entire dataset.
#
# **MonthlyIncome** A majority of the employees in the dataset earn between 2k to 11.5k. The maximum monthly income is less than 20k.
#
# **MonthlyRate** There seems to be no trend in this feature.
#
# **NumCompaniesWorked** Many employees (35%) have only worked in one company followed by those who have never worked before. Those who have worked for many companies like 5-9 companies before joining here have less than 9% of the dataset each.
#
# **Over18** This is a constant feature. It shows that all employees are above 18 years old.
#
# **OverTime** 72% of the employees in the dataset don't work overtime. Only 28% have overwork, either because it doesn't pay well or it rarely happens.
#
# **PercentSalaryHike** There seems to be a general trend that the more the salary hike the less number of employees that receive. More employees have 11% salary hike while the least have 25% salary hike.
#
# **PerformanceRating** It appears that the employees rated on either 4 point or 5 point scale, lie between 3 and 4 scales. 85% lie at 3 while 15% lie at 4th scale. This shows that all the employees performed their jobs well.
#
# **RelationshipSatisfaction** On a 4-point Likert scale on Relationship satisfaction, 31% rated the company at 3, while 29% rated 4. This mean the satisfaction is fairly good since 60% are satisfied. 21% rated at 2 while 19% rated 1%.
#
# **StandardHours** This is also a constant feature that shows that all had same standard hours.
#
# **StockOptionLevel** It appears that the more the stock option levels, the lesser the number of employee all the way from 0 to 3.
#
# **TotalWorkingHours** Many employees work between 5 to 12.5 hours. However, there seem to be a general trend that the more the number of years the fewer the employees.
#
# **TrainingTimesLastYear** It appears that many employees, actually 70% of the entire population had a training in the previous year, which may be an indicator ofupskilling in the company.
#
# **WorkLifeBalance** On a scale of 1 to 4,10% of the employees rated at 4, 61% of the employees rated at 3, 23% rated at 2 and 5% rated at 1 in terms of worklife balance. This means 71% of the employees somehow have a work life balance while 28% indicated lack of this balance.
#
# **YearsAtCompany** Many people have less than 10 years in the company. A general trend is that as the number of years at the company increases, the number of employees decreases proportionally.
#
# **YearsInCurrentRole** Again, many employees having been working in their current role in less than 10 years. After 10 years, the number decreases in each category. This indicates that in every 10 years employees are changing their roles, either due to other employees who may have left other roles vacant and hence the older staff fills in the gap or there is progressive upskilling that is increasing chances for role change.
#
# **YearSinceLastPromotion** Many employees were promoted in not more than 3 years ago. It is also evident that there are some who have taken 15 years since their last promotion. This can easily lead to attrition.
#
# **YearsWithManager** Many of the employees are those whose Years of working with current manager are less than 10 years and especially from 0 to 4 years. Holding all other factors constant, the current manager may not be friendly and this may have led to attrition of many employees hence finding new employees every 0-4 years. However, there seems to be people who have worked under the current manager for over 15 years.

# %% [markdown]
# #### b. Bivaraite Analysis checking relationship of all variables with respect to target variable.

# %%
data.head(1)
# Out:
#    Age Attrition BusinessTravel  DailyRate Department  DistanceFromHome  \
# 0   41       Yes  Travel_Rarely       1102      Sales                 1
#
#    Education EducationField  EmployeeCount  EmployeeNumber  \
# 0          2  Life Sciences              1               1
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2  Female          94               3         2
#
#            JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  MonthlyRate  \
# 0  Sales Executive                4        Single           5993        19479
#
#    NumCompaniesWorked Over18 OverTime  PercentSalaryHike  PerformanceRating  \
# 0                   8      Y      Yes                 11                  3
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                         1             80                 0
#
#    TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# ...

# %%
# Creating a list for categorical columns.
categorical_col = []
for column in data.columns:
    if data[column].dtype == object:
        categorical_col.append(column)
        print(f"{column} : {data[column].unique()}")
        print("====================================")
# Out:
# Attrition : ['Yes' 'No']
# ...
# BusinessTravel : ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# ...
# Department : ['Sales' 'Research & Development' 'Human Resources']
# ...
# EducationField : ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# ...
# Gender : ['Female' 'Male']
# ...
# JobRole : ['Sales Executive' 'Research Scientist' 'Laboratory Technician'
#  'Manufacturing Director' 'Healthcare Representative' 'Manager'
#  'Sales Representative' 'Research Director' 'Human Resources']
# ...
# MaritalStatus : ['Single' 'Married' 'Divorced']
# ...
# Over18 : ['Y']
# ...
# OverTime : ['Yes' 'No']
# ...

# %%
categorical_col
# Out:
# ['Attrition',
#  'BusinessTravel',
#  'Department',
#  'EducationField',
#  'Gender',
#  'JobRole',
#  'MaritalStatus',
#  'Over18',
#  'OverTime']

# %% [markdown]
# #### i) Categorical Data

# %%
## Create a new dataframe with categorical variables only
data1=data[categorical_col]

# %%
data1
# Out:
#      Attrition     BusinessTravel              Department EducationField  \
# 0          Yes      Travel_Rarely                   Sales  Life Sciences
# 1           No  Travel_Frequently  Research & Development  Life Sciences
# 2          Yes      Travel_Rarely  Research & Development          Other
# 3           No  Travel_Frequently  Research & Development  Life Sciences
# 4           No      Travel_Rarely  Research & Development        Medical
# ...        ...                ...                     ...            ...
# 1465        No  Travel_Frequently  Research & Development        Medical
# 1466        No      Travel_Rarely  Research & Development        Medical
# 1467        No      Travel_Rarely  Research & Development  Life Sciences
# 1468        No  Travel_Frequently                   Sales        Medical
# 1469        No      Travel_Rarely  Research & Development        Medical
#
#       Gender                    JobRole MaritalStatus Over18 OverTime
# ...

# %%
# Plotting how every  categorical feature correlate with the "target"
plt.figure(figsize=(14,20), facecolor='white')
plotnumber = 1

for column in data1:
    if plotnumber<=9 :
        ax = plt.subplot(5,2,plotnumber)
        sns.countplot(x=data1[column].dropna(axis=0)
                        ,hue=data.Attrition)
        plt.xlabel(column,fontsize=20)
        plt.ylabel('Attrition',fontsize=20)
        plt.title('{} against Attrition'.format(column))
        plt.xticks(rotation=15)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# ### Insights from Bivariate analysis of categorical data.
# * **Atrition:-** 83% of the employees didn't leave the company. Only 16% of the total employees left the company. The company is fairly good since it is capable of retaining such a great percentage of workers.
# * **BusinessTravel:-** As we saw in the univariate analysis, we had more employees who rarely travel followed by those who frequently travel and lastly those who do not travel. This same trend is seen when we correlate with the attrition. Those who rarely travel do not leave the company, while the workers who travel alot are more likely to quit than other employees..
# * **Departent:-** Research and Development department is experiencing the highest retention. This is because this department being very key in any products and service company since it  bring insights that help a company in understanding what consumers need and developing products that meet those standards.This could be the reason as to why there is a high retention. This is followed by sales department, which make sales, increase profitability, and build and maintain relationships with customers to encourage repeat purchases and brand loyalty, again an important department. Human Resource which had the lowest number of employees has the lest attrition.
# * **EducationField:-** In each field we have more employees retained as compared to those who quit.
# * **Gender:-** In every gender that is male and female, we have more retention than attrition. For male, over 700 out of 882 male employees are retained while in female over 500 out of 588 are retained. The company is good, employees are retained.
# * **JobRole:-** From the subplots above, all job roles have a general trend of have higher rention than attrition, however, Laboratory technitian, Sales Representative and Human Resources have increased number of those who quit job.
# * **MaritalStatus:-** Generally there is more retention than attrition in each status, however, for the single, there is an increased number of those quitting job.
# * **Over18:-** Out of 1470 employees, about 200 employees quit their job. We may not have clar information this the feature has a constant value (Y).
# * **OverTime:-** For those who work overtime and those who do not, there is more retention than attrition. It is however, clear that out of 416 employees who work extra time, only about 300 are retained. This shows us that there is high probability of employees quitting when working overtime. This could be because of issues such as life-work balance and maybe payments.|

# %% [markdown]
# #### ii) Numerical: Continous data

# %%
# Creating numerical list of columns with continous values
numerical_col = []
for column in data.columns:
    if data[column].dtype == 'int64' and len(data[column].unique())>= 10:
        numerical_col.append(column)

# %%
data2=data[numerical_col]
data2.head()
# Out:
#    Age  DailyRate  DistanceFromHome  EmployeeNumber  HourlyRate  \
# 0   41       1102                 1               1          94
# 1   49        279                 8               2          61
# 2   37       1373                 2               4          92
# 3   33       1392                 3               5          56
# 4   27        591                 2               7          40
#
#    MonthlyIncome  MonthlyRate  NumCompaniesWorked  PercentSalaryHike  \
# 0           5993        19479                   8                 11
# 1           5130        24907                   1                 23
# 2           2090         2396                   6                 15
# 3           2909        23159                   1                 11
# 4           3468        16632                   9                 12
#
#    TotalWorkingYears  YearsAtCompany  YearsInCurrentRole  \
# 0                  8               6                   4
# ...

# %%
# Plotting how every  numerical feature correlate with the "target"
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in data2:
    if plotnumber<=16 :
        ax = plt.subplot(4,4,plotnumber)
        sns.histplot(x=data2[column].dropna(axis=0)
                        ,hue=data.Attrition,multiple='dodge',kde=True)
        plt.xlabel(column,fontsize=20)
        plt.ylabel('Attrition',fontsize=20)
        plt.title('{} against Attrition'.format(column))
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# ### Insights from the continous numerical column
# * **Age:-** Below 20 years there is high attrition, the probability of retention increases from 20 years to about 30 years of age where we begin to see high retention of employees. This could be because young people are always looking for greener pastures and are therefore unsettled even in work places.
# * **DailyRate:-** It seems that whatever the daily rate is offered, retention is high as compared to attrition. However, below 600 daily rate, we have more people quitting job in comparison with the rest of the daily rate. This is expected since money is a motivation and hence the less the money given the more the attrition, and vice versa.
# * **DistanceFromHome:-** Whatever the amount of distance from home, we have more retention than attrition.
# * **EmployeeNumber:-** This is a redundant column.
# * **HourlyRate:-** This has no well defined trend. At whatever rate, there is more retention than attrition.
# * **MonthlyIncome:-** Although we have more employees with less than 10,000 pay monthly, those earning less than 2,500 monthly quit job more than they are retained. Above 2,500 monthly income, we have more retention than attrition. However, from 2,500 and above the probability of retention increases while that of attrition decreases till 20,000 monthly income. This could b because good wages motivate the employee.
# * **MonthlyRate:-** Just like HourlyRate, this has no trend, but it is clear that at whatever rate, the probability of retention is higher that attrition.
# * **NumCompaniesWorked:-** Whatever the number of companies one has worked the probability of retention is still higher. Those who have worked for less than 2 companies, have increased chances of attrition. Those who have worked in more than 2 companies have almost constant probability of attrition.
# * **PercentSalaryHike:-** Whatever amount of percentage salary hike, chances of retention are higher than attrition. However, the probability curve shows that as the amount of percent salary hike increases, the chances of attrition descrease. This is expected since increasing salary increases employee motivation and thus retaining the employee.
# * **TotalWorkingYears:-** Generally, for all the number of working years, the probability of retention is high as compared to attrition. It can still be witnessed that below 10 years, we have more employers quitting jobs as compared to other years. This trend however, seem to channge at 10 years and above where as the number of years increase, the probability of retention increases.
# * **YearsAtCompany:-** For the whole range of years spend in a company, retention chances are high as compared to attrition.
# * **YearInCurrentRole:-** The probability of retention is high nomatter the number of years an employee has spent in their current role. However for less than 2.5 years, the chances of attrition are high as compared to the rest of the years.
# * **YearsSinceLastPromotion:-** Still retention is high despite the number of years since one was promoted.
# * **YearsWithCurrentanager:-** Despite the number of years one has worked under the current manager, the probability of retention is high.

# %% [markdown]
# #### iii) Numerical: discrete data

# %%
# Getting a discrete column list
discrete_col = []
for column in data.columns:
    if data[column].dtype == 'int64' and len(data[column].unique()) < 10:
        discrete_col.append(column)

# %%
# Dataframe of the discrete columns
data3=data[discrete_col]
data3.head()
# Out:
#    Education  EmployeeCount  EnvironmentSatisfaction  JobInvolvement  \
# 0          2              1                        2               3
# 1          1              1                        3               2
# 2          2              1                        4               2
# 3          4              1                        4               3
# 4          1              1                        1               3
#
#    JobLevel  JobSatisfaction  PerformanceRating  RelationshipSatisfaction  \
# 0         2                4                  3                         1
# 1         2                2                  4                         4
# 2         1                3                  3                         2
# 3         1                3                  3                         3
# 4         1                2                  3                         4
#
#    StandardHours  StockOptionLevel  TrainingTimesLastYear  WorkLifeBalance
# ...

# %%
# Plotting how every  discrete feature correlate with the "target"
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in data3:
    if plotnumber<=16 :
        ax = plt.subplot(4,4,plotnumber)
        sns.countplot(x=data3[column].dropna(axis=0)
                        ,hue=data.Attrition,)
        plt.xlabel(column,fontsize=20)
        plt.ylabel('Attrition',fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# ### Insights from Discrete columns
# * **Education:-** For every level of education employees stay than quit job.
# * **EmployeeCount:-** This is a redundant column
# * **EnvironmentSatisfaction:-** Whatever number in the scale of environment satisfaction, we have more employees retained than those that quit. However environment satisfaction scale 1 has more employees who quit job than the rest of the the numbers in the scale.
# * **JobInvolvement:-** For all numbers in the job involvement scale, we have high probabilities for retaining employees than loosing them. However it appears that as the scale increases from 1 to 4, the number of employees retained increases. This could be because, the more the job is involving the more it affects other dimensions of life negatively and hence many may choose to quit the job.
# * **JobLevel:-** For whatever Job level, the employees retained are more than employees that quit the job. However, as the scale increases from 1 to 5, we see a decrease in the number employees who quit in comparison to those who are retained. May be as the job level increases there could be some benefits alongside that could decrease the number of those who quit job.
# * **JobSatisfaction:-**  In the entire scale ranging from 1 to 4, th company has more retained employees than those that quit. It appears that as the scale increases from 1 to 4, the number of the retained increases as compared to those that quit.
# * **PerformanceRating:-**  Those rated 4 have a higher chance of quiting than those rated 3. The reason is that the ones rated 3 may receive some benefits or even get promoted unlike those rated 4 thus encouraging attrition.
# * **RelationshipSatisfaction:-** The higher the relationship satisfaction rating, the more the retention.
# * **StandardHours:-** This is a constant feature and therefore has no trend.
# * **StockOptionLevel:-** Stock option level 1 and 2 have higher chances for retention as compared to stock option 0 and 3.
# * **TrainingTimesLastYear:-** As the number of training times in the previous year increases, the likelihood of retention increases.
# * **WorkLifeBalance:-** From the life work balance scale, it appears that from 1 to 3 we have an increase the the probabability of retention which decreases at rating 4.

# %% [markdown]
# >## Data Preprocessing

# %% [markdown]
# ### i) Dealing with missing values

# %%
## Checking missing values
data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# ### ii) Categorical data conversion

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
## Manual encoding Attrition feature
## map("old value":'new value')
data.Attrition=data.Attrition.map({'Yes':1,'No':0})

# %%
## Encoding BusinessTravel, this feature told the worker who travelled frequesnlty has quited the job so let do the
##manual encoding
data.BusinessTravel=data.BusinessTravel.map({'Travel_Frequently':1,'Travel_Rarely':2,'Non-Travel':0})
# the eda shows that those who travel frequently dont quit as those who rarely  so give it less weight 1.

# %%
# From the EDA R & S Department quit more followed by Sales and then HR department
data.Department=data.Department.map({'Research & Development':2,'Sales':1,'Human Resources':0})

# %%
data.EducationField=data.EducationField.map({'Life Sciences':5,'Medical':4,'Marketing':3,'Technical Degree':2,'Other':1,'Human Resources':0 })

# %%
## Encoding Gender 
data.Gender=pd.get_dummies(data.Gender,drop_first=True)

# %%
## Encoding JobRole
data.JobRole=data.JobRole.map({'Laboratory Technician':8,'Sales Executive':7,'Research Scientist':6,'Sales Representative':5,
                              'Human Resources':4,'Manufacturing Director':3,'Healthcare Representative':2,'Manager':1,'Research Director':0 })

# %%
## Encoding MaritalStatus
data.MaritalStatus=data.MaritalStatus.map({'Single':2,'Married':1,'Divorced':0})

# %%
## Encoding OverTime
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()
data.OverTime=label.fit_transform(data.OverTime)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   int64
#  2   BusinessTravel            1470 non-null   int64
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   int64
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   int64
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   uint8
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# >## Feature Selection

# %%
## Checking correlation
plt.figure(figsize=(30, 30))
sns.heatmap(data2.corr(), annot=True, cmap="RdYlGn", annot_kws={"size":15});

# %%
## Removing constant features
data.drop(['EmployeeCount', 'EmployeeNumber', 'Over18', 'StandardHours'], axis="columns", inplace=True)

# %%
data.describe()
# Out:
#                Age    Attrition  BusinessTravel    DailyRate   Department  \
# count  1470.000000  1470.000000     1470.000000  1470.000000  1470.000000
# mean     36.923810     0.161224        1.607483   802.485714     1.610884
# std       9.135373     0.367863        0.665455   403.509100     0.568893
# min      18.000000     0.000000        0.000000   102.000000     0.000000
# 25%      30.000000     0.000000        1.000000   465.000000     1.000000
# 50%      36.000000     0.000000        2.000000   802.000000     2.000000
# 75%      43.000000     0.000000        2.000000  1157.000000     2.000000
# max      60.000000     1.000000        2.000000  1499.000000     2.000000
#
#        DistanceFromHome    Education  EducationField  EnvironmentSatisfaction  \
# count       1470.000000  1470.000000     1470.000000              1470.000000
# mean           9.192517     2.912925        3.883673                 2.721769
# ...

# %% [markdown]
# ## Model Creation

# %%
## Creating independent and dependent variable
X = data.drop('Attrition', axis=1)
y = data.Attrition

# %%
data.Attrition.value_counts()
# Out:
# 0    1233
# 1     237
# Name: Attrition, dtype: int64

# %%
## Balancing the data
from collections import Counter
from imblearn.over_sampling import SMOTE
sm=SMOTE()
print(Counter(y))
X_sm,y_sm=sm.fit_resample(X,y)
print(Counter(y_sm))
# Out:
# Counter({0: 1233, 1: 237})
# Counter({1: 1233, 0: 1233})

# %%
## preparing training and testing data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_sm, y_sm, test_size=0.25, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(X_train,y_train)
y_hat=dt.predict(X_test)

# %%
## Evalauting the model
from sklearn.metrics import accuracy_score,classification_report,f1_score
## Training score
train_predict=dt.predict(X_train)
cc_train=accuracy_score(y_train,train_predict)
cc_train
# Out:
# 1.0

# %%
print(classification_report(y_train,train_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       922
#            1       1.00      1.00      1.00       927
#
#     accuracy                           1.00      1849
#    macro avg       1.00      1.00      1.00      1849
# weighted avg       1.00      1.00      1.00      1849

# %%
print(f1_score(y_train,train_predict))
# Out:
# 1.0

# %%
y_hat=dt.predict(X_test)

# %%
cc_test=accuracy_score(y_test,y_hat)
cc_test
# Out:
# 0.8022690437601296

# %%
print(classification_report(y_test,y_hat))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.79      0.80       311
#            1       0.79      0.81      0.80       306
#
#     accuracy                           0.80       617
#    macro avg       0.80      0.80      0.80       617
# weighted avg       0.80      0.80      0.80       617

# %%
print(f1_score(y_test,y_hat))
# Out:
# 0.8025682182985553

# %% [markdown]
# ### Insights from the model on training and testing data.
# From above we can say,the model has learnt the training data very well. The accuracy is 100% while f1 score is 1.0. However, the model dt is not performing very well on testing data, the accuracy is 82% which is lower than the training accuracy, the f1 score is 0.82 again lower that that obtained from training data. This condition where the model performs well on training data but poorly on testing is called `Overfitting`. We can tune the hyperparameters to improve the prediction.

# %% [markdown]
# ## Hyperparameters of DecisionTree

# %% [markdown]
# * criterion: The function to measure the quality of a split. Supported criteria are "gini" for the Gini impurity and "entropy" for the information gain.
#
#
# * splitter: The strategy used to choose the split at each node. Supported strategies are "best" to choose the best split and "random" to choose the best random split.
#
# * max_depth: It tells how deep the decision tree can be.The maximum depth of the tree.Deeper the tree more split it has and it captures mopre info from data.In general a DT overfits for large depth value.The tree perfectly fits the training data and fails to generalize on testing data.
#
# * min_samples_split: The minimum number of samples required to split an internal node.Ideal range is 1 to 40.
#
# * min_samples_leaf: The minimum number of samples required to be at a leaf node.Similarr to min sample split ,this describes the minimum number of samples at the leaf,the base of tree.Ideal range is 1 to 20.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score,classification_report,f1_score

# %%
# Fitting the grid search.
params = {
    "criterion":("gini", "entropy"), 
    "splitter":("best", "random"), 
    "max_depth":(list(range(10, 16))), 
    "min_samples_split":[2, 4, 6], 
    "min_samples_leaf":list(range(1, 10)), 
}


tree_clf = DecisionTreeClassifier(random_state=3)
tree_cv = GridSearchCV(tree_clf, params, scoring="f1", n_jobs=-1, verbose=2, cv=3)
tree_cv.fit(X_train,y_train)
best_params = tree_cv.best_params_
print(f"Best paramters: {best_params})")
# Out:
# Fitting 3 folds for each of 648 candidates, totalling 1944 fits
# Best paramters: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'})

# %%
print(f"Best paramters: {best_params})")
# Out:
# Best paramters: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'})

# %%
tree_cv.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 10,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'splitter': 'random'}

# %%
tree_cv.best_score_
# Out:
# 0.8208492117947189

# %%
dt1=DecisionTreeClassifier(criterion='gini',
                           max_depth=10,min_samples_leaf=1,
                           min_samples_split=2,splitter='random')

# %%
dt1.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=10, splitter='random')

# %%
y_hat1=dt1.predict(X_test)

# %%
test_accuracy=accuracy_score(y_test,y_hat1)
test_accuracy
# Out:
# 0.8249594813614263

# %%
test_f1=f1_score(y_test,y_hat1)
test_f1
# Out:
# 0.8307210031347961

# %%
print(classification_report(y_test,y_hat1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.78      0.82       311
#            1       0.80      0.87      0.83       306
#
#     accuracy                           0.82       617
#    macro avg       0.83      0.83      0.82       617
# weighted avg       0.83      0.82      0.82       617

# %% [markdown]
# ### Insights from tuned model.
# * **Phase 1**:- With Best paramters: {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}). The accuracy has improved from 82% to 84% while the f1 score has improved to 0.83, the cross validation score is 0.83. According to the classification report, both the precision and recall for all classs (0 and 1) are almost equal. This is fairly good, however for better performance the f1 score which is a weighted harmonic mean of both need to be increased by doing another hyperparameter tuning.
# * **Phase 2**:-With Best paramters: {'criterion': 'gini', 'max_depth': 14, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}). The accuracy scor has improved to 85%, the f1 score has improved to 0.85 while cross validation best score is 0.82. we may try to tune once more to see if we can improve the f1 score.
# * **Phase 3**:- With Best paramters: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}). The accuracy is reduced to 82% and the f1 score has also reduced to 0.83 as it was initially.
#
# Therefore according to the hyperparameter tuning so far, the best parameters for this model should be those of phase 2: `{'criterion': 'gini', 'max_depth': 14, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}.`

# %% [markdown]
# ## Decision Tree Visualization

# %%
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(dt,filled=True)
plt.show()

# %%
fn=['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome',
       'Education', 'EducationField', 'EnvironmentSatisfaction', 'Gender',
       'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole',
       'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate',
       'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
       'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel',
       'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
       'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
       'YearsWithCurrManager']
cn=['Yes','No']
fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (4,4), dpi=300)
tree.plot_tree(dt,
               feature_names = fn, 
               class_names=cn,
               filled = True);
#fig.savefig('imagename.png')
plt.show()

# %% [markdown]
# ## RandomForest Implementation

# %%
from sklearn.ensemble import RandomForestClassifier

rf_clf = RandomForestClassifier(n_estimators=100)
rf_clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_predict=rf_clf.predict(X_test)

# %%
from sklearn.metrics import classification_report,f1_score
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90       311
#            1       0.92      0.87      0.89       306
#
#     accuracy                           0.90       617
#    macro avg       0.90      0.90      0.90       617
# weighted avg       0.90      0.90      0.90       617

# %%
f_Score=f1_score(y_test,y_predict)
f_Score
# Out:
# 0.8944723618090452

# %% [markdown]
# ### Insights from Random Forest
# From random forest, we see that the accuracy is 91% while the f1 score is 0.91. This is exceptioally good prediction. However we may also tune the parameters to see if we can improve further the model to try to balance the scores in both classes or even improve them.

# %% [markdown]
# ### Random Forest Hyperparameter Tuning

# %% [markdown]
# * n_estimators = number of trees in the foreset
# * max_features = max number of features considered for creating the tree.
# * max_depth = max number of levels in each decision tree
# * min_samples_split = min number of data points placed in a node before the node is split
# * min_samples_leaf = min number of data points allowed in a leaf node
# * bootstrap = method for sampling data points (with or without replacement)

# %%
from sklearn.model_selection import RandomizedSearchCV

n_estimators = [int(x) for x in np.linspace(start=300, stop=500, num=20)]
max_features =['sqrt']
max_depth = [int(x) for x in np.linspace(20, 60, num=20)]
max_depth.append(None)
min_samples_split = [2,3,4]
min_samples_leaf = [1, 2, 3]


random_grid = {'n_estimators': n_estimators, 'max_features': max_features,
               'max_depth': max_depth, 'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

rf_clf1 = RandomForestClassifier(random_state=42)

rf_cv = RandomizedSearchCV(estimator=rf_clf1, scoring='f1',param_distributions=random_grid, n_iter=100, cv=3, 
                               verbose=3, random_state=42, n_jobs=-1)

rf_cv.fit(X_train, y_train)
rf_best_params = rf_cv.best_params_
print(f"Best paramters: {rf_best_params})")
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Best paramters: {'n_estimators': 426, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 30})

# %%
rf_clf2 = RandomForestClassifier(n_estimators= 426, min_samples_split= 2, min_samples_leaf= 1, max_features= 'sqrt', max_depth= 30)
rf_clf2.fit(X_train, y_train)
y_predict=rf_clf2.predict(X_test)

# %%
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.93      0.91       311
#            1       0.93      0.89      0.91       306
#
#     accuracy                           0.91       617
#    macro avg       0.91      0.91      0.91       617
# weighted avg       0.91      0.91      0.91       617

# %%
f1_score1=f1_score(y_test,y_predict)

# %%
f1_score1
# Out:
# 0.9099999999999999

# %% [markdown]
# ### Insights from Hyperparameter tuning of the Random Forest
# * **Phase 1**:- With Best paramters: {'n_estimators': 400, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'auto', 'max_depth': 30}), the accuracy maintains at 91%, the f1 score has also maintained at 0.91.
# * **Phase 2**:- With Best paramters: {'n_estimators': 184, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 18}), has accuracy has gone lower to 90% and f1 score of 0.89.
# * **Phase 3**:- With Best paramters: {'n_estimators': 500, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 42}), the accuracy has gone up again to 91%, while the f1 score is low at 0.90.
# * **Phase 4** :- With Best paramters: {'n_estimators': 400, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 27}), the accuracy is 91% while f1 score is 0.90.
# * **Phase 5**:- With Best paramters: {'n_estimators': 426, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 30}), the accuracy remains at 91% while the f1 score improves to 0.91.
#
# In **phase 5 and phase 1**, yield the same results but under different set of hyperparameters. However, the hyperparameter 'Max_features' = 'auto' in Phase 1 is deprecated and therefore the set of hyperparameters in **Phase 5 give the best performance of the model on the testing data.**

# %% [markdown]
# ## Conclusion
# >+ When the 2 algorithms are compared in this businness case of classifying employee attrition, it can demonstrated clearly that **Random Forest algorithm surpasses Decision Tree** *before and even after hyperparameter tuning*.
# >+ After hyperparameter tuning, the **testing accuracy for the Random Forest was found to be 91%** while that of **Decision Tree was 85%**. The **f1 score for Random Forest was found to be 0.91** while that of **Decision Tree was 0.85**. This helps us to understand that Random Forest algorithm has a higher performance efficiency/accuracy as compared to decision tree. This is because it is build on the principle of `bagging` where the final output is obtained through majority (hard) vote.
# >+ The only <u>dissadvantage</u> I faced while performing this task was that the <u>training time for Random Forest was more compared to Decision Tree</u> due to its complexity. This is expected because whenever it has to make a prediction each decision tree has to generate output for the given input data.
